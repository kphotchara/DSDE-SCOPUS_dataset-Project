# %%
import pandas as pd
import ast
import numpy as np

# %%
data_2018 = pd.read_csv('output_2018.csv',low_memory=False)
data_2019 = pd.read_csv('output_2019.csv',low_memory=False)
data_2020 = pd.read_csv('output_2020.csv',low_memory=False)
data_2021 = pd.read_csv('output_2021.csv',low_memory=False)
data_2022 = pd.read_csv('output_2022.csv',low_memory=False)
data_2023 = pd.read_csv('output_2023.csv',low_memory=False)

for year in [2018, 2019, 2020, 2021, 2022, 2023]:
  print(eval(f'data_{year}').shape)
# Out:
# (2792, 310)
# (3082, 310)
# (3393, 318)
# (3815, 302)
# (4244, 288)
# (2890, 297)

# %%
data = pd.concat([data_2018, data_2019, data_2020, data_2021, data_2022, data_2023], ignore_index=True)
data.shape
# Out:
# (20216, 333)

# %%
# Rename columns
new_columns = {
    'title': 'title',
    'abstracts-retrieval-response.subject-areas.subject-area': 'subject_areas',
    'abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.year': 'publication_year',
    'aggregationType': 'aggregation_type',
    'abstracts-retrieval-response.item.bibrecord.tail.bibliography.@refcount': 'reference_count',
    'abstracts-retrieval-response.coredata.openaccess': 'open_access',
    'publisher': 'publisher',
    'funding-list.@has-funding-info': 'has_funding_info',
    'abstracts-retrieval-response.authkeywords.author-keyword' :'keywords',
    'abstracts-retrieval-response.coredata.citedby-count': 'citation_count'
}

# Rename the columns in the DataFrame
data.rename(columns=new_columns, inplace=True)


# Select the target variable
target_column = 'open_access'

# Select the features
features = list(new_columns.values())
features.remove(target_column)


# Check if all columns exist in the dataframe
missing_columns = set(features) - set(data.columns)
if missing_columns:
    print(f"Warning: The following features are not in the dataframe: {missing_columns}")
    features = [col for col in features if col in data.columns]


# Create a new DataFrame with selected features and the target variable
selected_data = data[['filename']+features + [target_column]]

# Display the first few rows of the selected data
selected_data.head()
# Out:
#     filename                                              title  \
# 0  201800282  Recent developments in bifunctional air electr...
# 1  201801350  The benefit of punishment sensitivity on motor...
# 2  201801162  MAGIC biomarkers predict long-term outcomes fo...
# 3  201801506  Are endocrine disrupting compounds environment...
# 4  201802383  Probabilistic regular grammar inference algori...
#
#                                        subject_areas  publication_year  \
# 0  [{'@_fa': 'true', '$': 'Renewable Energy, Sust...              2018
# 1  [{'@_fa': 'true', '$': 'Social Psychology', '@...              2018
# 2  [{'@_fa': 'true', '$': 'Biochemistry', '@code'...              2018
# 3  [{'@_fa': 'true', '$': 'Endocrinology', '@code...              2018
# 4  [{'@_fa': 'true', '$': 'Information Systems', ...              2018
#
#         aggregation_type  reference_count  \
# 0                Journal             89.0
# 1                Journal             44.0
# 2                Journal             30.0
# 3                Journal            128.0
# 4  Conference Proceeding              9.0
#
#                                            publisher  has_funding_info  \
# 0                                       Elsevier Ltd               1.0
# 1                           Blackwell Publishing Ltd               NaN
# 2                     American Society of Hematology               1.0
# 3              Academic Press Inc.apjcs@harcourt.com               1.0
# 4  International Workshop on Computer Science and...               1.0
#
#                                             keywords  citation_count  \
# 0  [{'@_fa': 'true', '$': 'Bifunctional air elect...            29.0
# 1  [{'@_fa': 'true', '$': 'anxiety'}, {'@_fa': 't...             2.0
# 2                                                NaN           117.0
# 3  [{'@_fa': 'true', '$': 'Autism'}, {'@_fa': 'tr...            51.0
# 4  [{'@_fa': 'true', '$': 'Grammar inference'}, {...             0.0
#
#    open_access
# 0          0.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          NaN

# %%
missing_values = selected_data.isnull().sum()
print("Missing Values per Column:")
print(missing_values)
# Out:
# Missing Values per Column:
# filename               0
# title                  1
# subject_areas          0
# publication_year       0
# aggregation_type       0
# reference_count      411
# publisher             11
# has_funding_info    3428
# keywords            3804
# citation_count         4
# open_access         1668
# dtype: int64

# %%
selected_data = selected_data.dropna(subset=['title'])
selected_data = selected_data.dropna(subset=['open_access'])

# %%
# Fill missing 'Reference Count' with the mean
selected_data['reference_count'] = selected_data['reference_count'].fillna(selected_data['reference_count'].mean())

# Verify the imputation
missing_values_after_imputation_refCount = selected_data.isnull().sum()
print("Missing Values per Column:")
print(missing_values_after_imputation_refCount)
# Out:
# Missing Values per Column:
# filename               0
# title                  0
# subject_areas          0
# publication_year       0
# aggregation_type       0
# reference_count        0
# publisher              8
# has_funding_info    3016
# keywords            3545
# citation_count         2
# open_access            0
# dtype: int64

# %%
selected_data['citation_count'] = selected_data['citation_count'].fillna(selected_data['citation_count'].mean())

# Verify the imputation
missing_values_after_citation_imputation = selected_data.isnull().sum()
print("Missing Values per Column After Imputation:")
print(missing_values_after_citation_imputation)
# Out:
# Missing Values per Column After Imputation:
# filename               0
# title                  0
# subject_areas          0
# publication_year       0
# aggregation_type       0
# reference_count        0
# publisher              8
# has_funding_info    3016
# keywords            3545
# citation_count         0
# open_access            0
# dtype: int64

# %%
selected_data.dropna(subset=['publisher'], inplace=True)

# Verify that rows with missing 'Publisher' have been removed
missing_values_after_publisher_drop = selected_data.isnull().sum()
print("Missing Values per Column After Dropping rows with missing Publisher:")
print(missing_values_after_publisher_drop)
# Out:
# Missing Values per Column After Dropping rows with missing Publisher:
# filename               0
# title                  0
# subject_areas          0
# publication_year       0
# aggregation_type       0
# reference_count        0
# publisher              0
# has_funding_info    3013
# keywords            3544
# citation_count         0
# open_access            0
# dtype: int64

# %%
selected_data['has_funding_info'] = selected_data['has_funding_info'].fillna(0)

# Verify the imputation
missing_values_after_imputation_funding = selected_data.isnull().sum()
print("Missing Values per Column After Imputation:")
print(missing_values_after_imputation_funding)
# Out:
# Missing Values per Column After Imputation:
# filename               0
# title                  0
# subject_areas          0
# publication_year       0
# aggregation_type       0
# reference_count        0
# publisher              0
# has_funding_info       0
# keywords            3544
# citation_count         0
# open_access            0
# dtype: int64

# %%
selected_data.describe()
# Out:
#            filename  publication_year  reference_count  has_funding_info  \
# count  1.854000e+04      18540.000000     18540.000000      18540.000000
# mean   2.020672e+08       2020.654908        47.198624          0.837487
# std    1.625926e+05          1.624594        53.792437          0.368931
# min    2.018000e+08       2018.000000         1.000000          0.000000
# 25%    2.019024e+08       2019.000000        26.000000          1.000000
# 50%    2.021010e+08       2021.000000        40.000000          1.000000
# 75%    2.022022e+08       2022.000000        56.000000          1.000000
# max    2.023029e+08       2023.000000      4084.000000          1.000000
#
#        citation_count   open_access
# count    18540.000000  18540.000000
# mean         9.930467      0.588889
# std         28.195993      0.573829
# min          0.000000      0.000000
# 25%          1.000000      0.000000
# 50%          3.000000      1.000000
# 75%         10.000000      1.000000
# max       1356.000000      2.000000

# %%
def process_subject_areas(subject_areas_str):
    try:
        subject_areas = ast.literal_eval(subject_areas_str)
        if isinstance(subject_areas, list):
            subject_name = []
            subject_code = []
            subject_abbreviation = []
            for subject in subject_areas:
                subject_name.append(subject.get('$', ''))
                subject_code.append(subject.get('@code', ''))
                subject_abbreviation.append(subject.get('@abbrev', ''))
            return ', '.join(subject_name), ', '.join(subject_code), ', '.join(subject_abbreviation)
        else:
            return '', '', ''
    except (SyntaxError, ValueError):
        return '', '', ''

# Apply the function to the 'Subject Areas' column
selected_data[['subject_name', 'subject_code', 'subject_abbreviation']] = selected_data['subject_areas'].apply(lambda x: pd.Series(process_subject_areas(x)))

# Display the updated DataFrame
selected_data.head()
# Out:
#     filename                                              title  \
# 0  201800282  Recent developments in bifunctional air electr...
# 1  201801350  The benefit of punishment sensitivity on motor...
# 2  201801162  MAGIC biomarkers predict long-term outcomes fo...
# 3  201801506  Are endocrine disrupting compounds environment...
# 5  201801734  Optimization of cinnamon oil nanoemulsions usi...
#
#                                        subject_areas  publication_year  \
# 0  [{'@_fa': 'true', '$': 'Renewable Energy, Sust...              2018
# 1  [{'@_fa': 'true', '$': 'Social Psychology', '@...              2018
# 2  [{'@_fa': 'true', '$': 'Biochemistry', '@code'...              2018
# 3  [{'@_fa': 'true', '$': 'Endocrinology', '@code...              2018
# 5  [{'@_fa': 'true', '$': 'Electronic, Optical an...              2018
#
#   aggregation_type  reference_count                              publisher  \
# 0          Journal             89.0                           Elsevier Ltd
# 1          Journal             44.0               Blackwell Publishing Ltd
# 2          Journal             30.0         American Society of Hematology
# 3          Journal            128.0  Academic Press Inc.apjcs@harcourt.com
# 5          Journal             43.0  Academic Press Inc.apjcs@harcourt.com
#
#    has_funding_info                                           keywords  \
# 0               1.0  [{'@_fa': 'true', '$': 'Bifunctional air elect...
# 1               0.0  [{'@_fa': 'true', '$': 'anxiety'}, {'@_fa': 't...
# 2               1.0                                                NaN
# 3               1.0  [{'@_fa': 'true', '$': 'Autism'}, {'@_fa': 'tr...
# 5               1.0  [{'@_fa': 'true', '$': 'Cinnamon oil'}, {'@_fa...
#
#    citation_count  open_access  \
# 0            29.0          0.0
# 1             2.0          2.0
# 2           117.0          1.0
# 3            51.0          1.0
# 5            93.0          0.0
#
#                                         subject_name            subject_code  \
# 0  Renewable Energy, Sustainability and the Envir...  2105, 2103, 3104, 2102
# 1                                  Social Psychology                    3207
# 2  Biochemistry, Immunology, Hematology, Cell Bio...  1303, 2403, 2720, 1307
# 3  Endocrinology, Endocrine and Autonomic Systems...        1310, 2807, 2802
# 5  Electronic, Optical and Magnetic Materials, Bi...  2504, 2502, 2508, 1505
#
#      subject_abbreviation
# 0  ENER, ENER, PHYS, ENER
# 1                    PSYC
# 2  BIOC, IMMU, MEDI, BIOC
# 3        BIOC, NEUR, NEUR
# 5  MATE, MATE, MATE, CENG

# %%
# Calculate the age of the work
current_year = 2024  # Replace with the current year
selected_data['age_of_paper'] = current_year - selected_data['publication_year']

# Display the updated DataFrame with the 'Age' column
selected_data.head()
# Out:
#     filename                                              title  \
# 0  201800282  Recent developments in bifunctional air electr...
# 1  201801350  The benefit of punishment sensitivity on motor...
# 2  201801162  MAGIC biomarkers predict long-term outcomes fo...
# 3  201801506  Are endocrine disrupting compounds environment...
# 5  201801734  Optimization of cinnamon oil nanoemulsions usi...
#
#                                        subject_areas  publication_year  \
# 0  [{'@_fa': 'true', '$': 'Renewable Energy, Sust...              2018
# 1  [{'@_fa': 'true', '$': 'Social Psychology', '@...              2018
# 2  [{'@_fa': 'true', '$': 'Biochemistry', '@code'...              2018
# 3  [{'@_fa': 'true', '$': 'Endocrinology', '@code...              2018
# 5  [{'@_fa': 'true', '$': 'Electronic, Optical an...              2018
#
#   aggregation_type  reference_count                              publisher  \
# 0          Journal             89.0                           Elsevier Ltd
# 1          Journal             44.0               Blackwell Publishing Ltd
# 2          Journal             30.0         American Society of Hematology
# 3          Journal            128.0  Academic Press Inc.apjcs@harcourt.com
# 5          Journal             43.0  Academic Press Inc.apjcs@harcourt.com
#
#    has_funding_info                                           keywords  \
# 0               1.0  [{'@_fa': 'true', '$': 'Bifunctional air elect...
# 1               0.0  [{'@_fa': 'true', '$': 'anxiety'}, {'@_fa': 't...
# 2               1.0                                                NaN
# 3               1.0  [{'@_fa': 'true', '$': 'Autism'}, {'@_fa': 'tr...
# 5               1.0  [{'@_fa': 'true', '$': 'Cinnamon oil'}, {'@_fa...
#
#    citation_count  open_access  \
# 0            29.0          0.0
# 1             2.0          2.0
# 2           117.0          1.0
# 3            51.0          1.0
# 5            93.0          0.0
#
#                                         subject_name            subject_code  \
# 0  Renewable Energy, Sustainability and the Envir...  2105, 2103, 3104, 2102
# 1                                  Social Psychology                    3207
# 2  Biochemistry, Immunology, Hematology, Cell Bio...  1303, 2403, 2720, 1307
# 3  Endocrinology, Endocrine and Autonomic Systems...        1310, 2807, 2802
# 5  Electronic, Optical and Magnetic Materials, Bi...  2504, 2502, 2508, 1505
#
#      subject_abbreviation  age_of_paper
# 0  ENER, ENER, PHYS, ENER             6
# 1                    PSYC             6
# 2  BIOC, IMMU, MEDI, BIOC             6
# 3        BIOC, NEUR, NEUR             6
# 5  MATE, MATE, MATE, CENG             6

# %%
selected_data.head()
# Out:
#     filename                                              title  \
# 0  201800282  Recent developments in bifunctional air electr...
# 1  201801350  The benefit of punishment sensitivity on motor...
# 2  201801162  MAGIC biomarkers predict long-term outcomes fo...
# 3  201801506  Are endocrine disrupting compounds environment...
# 5  201801734  Optimization of cinnamon oil nanoemulsions usi...
#
#                                        subject_areas  publication_year  \
# 0  [{'@_fa': 'true', '$': 'Renewable Energy, Sust...              2018
# 1  [{'@_fa': 'true', '$': 'Social Psychology', '@...              2018
# 2  [{'@_fa': 'true', '$': 'Biochemistry', '@code'...              2018
# 3  [{'@_fa': 'true', '$': 'Endocrinology', '@code...              2018
# 5  [{'@_fa': 'true', '$': 'Electronic, Optical an...              2018
#
#   aggregation_type  reference_count                              publisher  \
# 0          Journal             89.0                           Elsevier Ltd
# 1          Journal             44.0               Blackwell Publishing Ltd
# 2          Journal             30.0         American Society of Hematology
# 3          Journal            128.0  Academic Press Inc.apjcs@harcourt.com
# 5          Journal             43.0  Academic Press Inc.apjcs@harcourt.com
#
#    has_funding_info                                           keywords  \
# 0               1.0  [{'@_fa': 'true', '$': 'Bifunctional air elect...
# 1               0.0  [{'@_fa': 'true', '$': 'anxiety'}, {'@_fa': 't...
# 2               1.0                                                NaN
# 3               1.0  [{'@_fa': 'true', '$': 'Autism'}, {'@_fa': 'tr...
# 5               1.0  [{'@_fa': 'true', '$': 'Cinnamon oil'}, {'@_fa...
#
#    citation_count  open_access  \
# 0            29.0          0.0
# 1             2.0          2.0
# 2           117.0          1.0
# 3            51.0          1.0
# 5            93.0          0.0
#
#                                         subject_name            subject_code  \
# 0  Renewable Energy, Sustainability and the Envir...  2105, 2103, 3104, 2102
# 1                                  Social Psychology                    3207
# 2  Biochemistry, Immunology, Hematology, Cell Bio...  1303, 2403, 2720, 1307
# 3  Endocrinology, Endocrine and Autonomic Systems...        1310, 2807, 2802
# 5  Electronic, Optical and Magnetic Materials, Bi...  2504, 2502, 2508, 1505
#
#      subject_abbreviation  age_of_paper
# 0  ENER, ENER, PHYS, ENER             6
# 1                    PSYC             6
# 2  BIOC, IMMU, MEDI, BIOC             6
# 3        BIOC, NEUR, NEUR             6
# 5  MATE, MATE, MATE, CENG             6

# %%
# Drop the 'subject_areas' column
selected_data = selected_data.drop('subject_areas', axis=1)

# %%
selected_data['subject_code'].head()
# Out:
# 0    2105, 2103, 3104, 2102
# 1                      3207
# 2    1303, 2403, 2720, 1307
# 3          1310, 2807, 2802
# 5    2504, 2502, 2508, 1505
# Name: subject_code, dtype: object

# %%
subject_to_supergroup = {
    '1000': 'Multidisciplinary',
    '1100': 'Life Sciences',  # Agricultural and Biological Sciences
    '1200': 'Social Sciences',  # Arts and Humanities
    '1300': 'Life Sciences',  # Biochemistry, Genetics and Molecular Biology
    '1400': 'Social Sciences',  # Business, Management, and Accounting
    '1500': 'Physical Sciences',  # Chemical Engineering
    '1600': 'Physical Sciences',  # Chemistry
    '1700': 'Physical Sciences',  # Computer Science
    '1800': 'Social Sciences',  # Decision Sciences
    '1900': 'Physical Sciences',  # Earth and Planetary Sciences
    '2000': 'Social Sciences',  # Economics, Econometrics and Finance
    '2100': 'Physical Sciences',  # Energy
    '2200': 'Physical Sciences',  # Engineering
    '2300': 'Physical Sciences',  # Environmental Science
    '2400': 'Life Sciences',  # Immunology and Microbiology
    '2500': 'Physical Sciences',  # Materials Science
    '2600': 'Physical Sciences',  # Mathematics
    '2700': 'Health Sciences',  # Medicine
    '2800': 'Life Sciences',  # Neuroscience
    '2900': 'Health Sciences',  # Nursing
    '3000': 'Life Sciences',  # Pharmacology, Toxicology, and Pharmaceutics
    '3100': 'Physical Sciences',  # Physics and Astronomy
    '3200': 'Social Sciences',  # Psychology
    '3300': 'Social Sciences',  # Social Sciences
    '3400': 'Health Sciences',  # Veterinary
    '3500': 'Health Sciences',  # Dentistry
    '3600': 'Health Sciences'  # Health Professions
}

# %%
def map_to_supergroup(subject_codes):
    codes = subject_codes.split(', ')  # Split subject codes into a list
    supergroups = []
    
    for code in codes:
        prefix = code[:2]  # Get the first two digits of the code
        matching_supergroup = None
        
        # Check if the prefix matches any key in the subject_to_supergroup dictionary
        for key, value in subject_to_supergroup.items():
            if key.startswith(prefix):  # If the first two digits match
                matching_supergroup = value
                break
        
        supergroups.append(matching_supergroup if matching_supergroup else 'Unknown')  # Append result
    
    return ', '.join(set(supergroups))  # Join the different supergroups into a result

# Use the function to map subject_code to Supergroup
selected_data['supergroup'] = selected_data['subject_code'].apply(map_to_supergroup)

# %%
selected_data['supergroup'].value_counts()
# Out:
# supergroup
# Physical Sciences                                                     6443
# Health Sciences                                                       3889
# Life Sciences                                                         1900
# Health Sciences, Life Sciences                                        1787
# Physical Sciences, Life Sciences                                      1129
# Social Sciences                                                        963
# Multidisciplinary                                                      924
# Physical Sciences, Social Sciences                                     782
# Physical Sciences, Health Sciences                                     208
# Health Sciences, Social Sciences                                       152
# Physical Sciences, Life Sciences, Health Sciences                       92
# Physical Sciences, Life Sciences, Social Sciences                       80
# Health Sciences, Life Sciences, Social Sciences                         52
# Life Sciences, Social Sciences                                          39
# Physical Sciences, Health Sciences, Life Sciences                       37
# Multidisciplinary, Life Sciences                                        28
# Physical Sciences, Social Sciences, Health Sciences                     20
# Physical Sciences, Health Sciences, Social Sciences                      6
# Multidisciplinary, Physical Sciences, Life Sciences                      4
# Physical Sciences, Health Sciences, Life Sciences, Social Sciences       3
# Multidisciplinary, Physical Sciences                                     2
# Name: count, dtype: int64

# %%
selected_data['supergroup'] = selected_data['supergroup'].apply(lambda x: 'Multidisciplinary' if ',' in x else x)
selected_data['supergroup'].value_counts()
# Out:
# supergroup
# Physical Sciences    6443
# Multidisciplinary    5345
# Health Sciences      3889
# Life Sciences        1900
# Social Sciences       963
# Name: count, dtype: int64

# %%
def extract_keywords(row):
    if pd.isna(row):  # ถ้าข้อมูลเป็น NaN ให้คืนค่า "No keyword"
        return "No keyword"
    try:
        # แปลง string เป็น list ของ dictionary
        items = ast.literal_eval(row)
        keywords = [item['$'] for item in items if '$' in item]
        return ", ".join(keywords) if keywords else "No keyword"
    except (ValueError, SyntaxError, TypeError):  # จัดการข้อผิดพลาด
        return "No keyword"


selected_data['keywords'] = selected_data['keywords'].apply(extract_keywords)

# %%
selected_data['keywords'].head()
# Out:
# 0    Bifunctional air electrode, Catalyst support, ...
# 1    anxiety, defensive distance, performance, rein...
# 2                                           No keyword
# 3    Autism, Endocrine disrupting compounds, Epigen...
# 5    Cinnamon oil, Nanoemulsions, Natural product, ...
# Name: keywords, dtype: object

# %%
selected_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18540 entries, 0 to 20215
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   filename              18540 non-null  int64
#  1   title                 18540 non-null  object
#  2   publication_year      18540 non-null  int64
#  3   aggregation_type      18540 non-null  object
#  4   reference_count       18540 non-null  float64
#  5   publisher             18540 non-null  object
#  6   has_funding_info      18540 non-null  float64
#  7   keywords              18540 non-null  object
#  8   citation_count        18540 non-null  float64
#  9   open_access           18540 non-null  float64
#  10  subject_name          18540 non-null  object
#  11  subject_code          18540 non-null  object
#  12  subject_abbreviation  18540 non-null  object
#  13  age_of_paper          18540 non-null  int64
#  14  supergroup            18540 non-null  object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 2.3+ MB

# %%
# Reorder the columns
new_column_order = ['filename','title','subject_name','subject_abbreviation','subject_code','supergroup','keywords','publication_year', 'age_of_paper','aggregation_type', 'reference_count', 'publisher', 'has_funding_info', 'citation_count','open_access']
selected_data = selected_data[new_column_order]

# Display the updated DataFrame
selected_data.head()
# Out:
#     filename                                              title  \
# 0  201800282  Recent developments in bifunctional air electr...
# 1  201801350  The benefit of punishment sensitivity on motor...
# 2  201801162  MAGIC biomarkers predict long-term outcomes fo...
# 3  201801506  Are endocrine disrupting compounds environment...
# 5  201801734  Optimization of cinnamon oil nanoemulsions usi...
#
#                                         subject_name    subject_abbreviation  \
# 0  Renewable Energy, Sustainability and the Envir...  ENER, ENER, PHYS, ENER
# 1                                  Social Psychology                    PSYC
# 2  Biochemistry, Immunology, Hematology, Cell Bio...  BIOC, IMMU, MEDI, BIOC
# 3  Endocrinology, Endocrine and Autonomic Systems...        BIOC, NEUR, NEUR
# 5  Electronic, Optical and Magnetic Materials, Bi...  MATE, MATE, MATE, CENG
#
#              subject_code         supergroup  \
# 0  2105, 2103, 3104, 2102  Physical Sciences
# 1                    3207    Social Sciences
# 2  1303, 2403, 2720, 1307  Multidisciplinary
# 3        1310, 2807, 2802      Life Sciences
# 5  2504, 2502, 2508, 1505  Physical Sciences
#
#                                             keywords  publication_year  \
# 0  Bifunctional air electrode, Catalyst support, ...              2018
# 1  anxiety, defensive distance, performance, rein...              2018
# 2                                         No keyword              2018
# 3  Autism, Endocrine disrupting compounds, Epigen...              2018
# 5  Cinnamon oil, Nanoemulsions, Natural product, ...              2018
#
#    age_of_paper aggregation_type  reference_count  \
# 0             6          Journal             89.0
# 1             6          Journal             44.0
# 2             6          Journal             30.0
# 3             6          Journal            128.0
# 5             6          Journal             43.0
#
#                                publisher  has_funding_info  citation_count  \
# 0                           Elsevier Ltd               1.0            29.0
# 1               Blackwell Publishing Ltd               0.0             2.0
# 2         American Society of Hematology               1.0           117.0
# 3  Academic Press Inc.apjcs@harcourt.com               1.0            51.0
# 5  Academic Press Inc.apjcs@harcourt.com               1.0            93.0
#
#    open_access
# 0          0.0
# 1          2.0
# 2          1.0
# 3          1.0
# 5          0.0

# %%
# Convert 'Reference Count', 'Publication Year', 'Has Funding Info', and 'Citation Count' to integers
selected_data['reference_count'] = selected_data['reference_count'].astype(int)
selected_data['open_access'] = selected_data['open_access'].astype(int)
selected_data['publication_year'] = selected_data['publication_year'].astype(int)
selected_data['has_funding_info'] = selected_data['has_funding_info'].astype(int)
selected_data['citation_count'] = selected_data['citation_count'].astype(int)

selected_data.dtypes
# Out:
# filename                 int64
# title                   object
# subject_name            object
# subject_abbreviation    object
# subject_code            object
# supergroup              object
# keywords                object
# publication_year         int64
# age_of_paper             int64
# aggregation_type        object
# reference_count          int64
# publisher               object
# has_funding_info         int64
# citation_count           int64
# open_access              int64
# dtype: object

# %%
data_web_to_science = pd.read_csv('web_to_science.csv',low_memory=False)

# %%
data_web_to_science.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1915 entries, 0 to 1914
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1915 non-null   int64
#  1   title             1915 non-null   object
#  2   publication_year  1915 non-null   int64
#  3   age_of_paper      1915 non-null   int64
#  4   aggregation_type  1915 non-null   object
#  5   reference_count   1915 non-null   int64
#  6   open_access       1915 non-null   int64
#  7   has_funding_info  488 non-null    object
#  8   citation_count    1915 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 134.8+ KB

# %%
data_web_to_science = data_web_to_science[data_web_to_science['publication_year'] >= 2018]
data_web_to_science.reset_index(drop=True, inplace=True)

# %%
print(data_web_to_science.describe())
# Out:
#         Unnamed: 0  publication_year  age_of_paper  reference_count  \
# count  1232.000000       1232.000000   1232.000000      1232.000000
# mean   1126.357143       2022.845779      1.154221        48.827110
# std     610.593997          1.547698      1.547698        50.080538
# min       0.000000       2018.000000      0.000000         0.000000
# 25%     382.500000       2023.000000      0.000000        21.000000
# 50%    1298.500000       2023.000000      1.000000        38.000000
# 75%    1606.250000       2024.000000      1.000000        62.000000
# max    1914.000000       2024.000000      6.000000       514.000000
#
#        open_access  citation_count
# count  1232.000000     1232.000000
# mean      1.693994        3.553571
# std       0.461020       11.138609
# min       1.000000        0.000000
# 25%       1.000000        0.000000
# 50%       2.000000        0.000000
# 75%       2.000000        3.000000
# max       2.000000      195.000000

# %%
data_web_to_science.drop(columns=['aggregation_type'], inplace=True)
data_web_to_science.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data_web_to_science.head()
# Out:
#                                                title  publication_year  \
# 0  An hybrid soft attention based XGBoost model f...              2023
# 1  Parasitic egg recognition using convolution an...              2023
# 2  Spatiotemporal changes of gross primary produc...              2024
# 3                               Cases of Castigation              2024
# 4  Understanding Underdevelopment: A Study on Sel...              2024
#
#    age_of_paper  reference_count  open_access  \
# 0             1               38            2
# 1             1               62            1
# 2             0               83            2
# 3             0               18            2
# 4             0               34            2
#
#                                     has_funding_info  citation_count
# 0                                                NaN               1
# 1  Funding\nThis research project was funded by M...               5
# 2                                                NaN               4
# 3                                                NaN               0
# 4                                                NaN               0

# %%
# เลือกคอลัมน์ที่ต้องการจาก selected_data และ data_web_to_science
selected_columns = ['title', 'age_of_paper', 'reference_count', 'citation_count', 'open_access']

# รวมข้อมูล
selected_data_training = pd.concat([selected_data[selected_columns], data_web_to_science[selected_columns]], ignore_index=True)

# แสดงข้อมูลที่รวมแล้ว
selected_data_training.head()
# Out:
#                                                title  age_of_paper  \
# 0  Recent developments in bifunctional air electr...             6
# 1  The benefit of punishment sensitivity on motor...             6
# 2  MAGIC biomarkers predict long-term outcomes fo...             6
# 3  Are endocrine disrupting compounds environment...             6
# 4  Optimization of cinnamon oil nanoemulsions usi...             6
#
#    reference_count  citation_count  open_access
# 0               89              29            0
# 1               44               2            2
# 2               30             117            1
# 3              128              51            1
# 4               43              93            0

# %%
selected_data_training['reference_count_log'] = np.log1p(selected_data_training['reference_count'])  # ใช้ log(1+x)
selected_data_training['citation_count_log'] = np.log1p(selected_data_training['citation_count'])

# %%
selected_data_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19772 entries, 0 to 19771
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                19772 non-null  object
#  1   age_of_paper         19772 non-null  int64
#  2   reference_count      19772 non-null  int64
#  3   citation_count       19772 non-null  int64
#  4   open_access          19772 non-null  int64
#  5   reference_count_log  19772 non-null  float64
#  6   citation_count_log   19772 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 1.1+ MB

# %%
selected_data_training.to_csv('selected_data_training.csv', index=False)

# %%
supergroup_counts = selected_data['supergroup'].value_counts().reset_index()
supergroup_counts.columns = ['supergroup', 'count']
supergroup_counts 
supergroup_counts.to_csv('supergroup_counts.csv', index=False)

# %%
import pandas as pd
import ast
from collections import Counter

# แยก keywords ออกเป็น list
selected_data['keywords_list'] = selected_data['keywords'].apply(lambda x: x.split(", ") if x != "No keyword" else [])

# ฟังก์ชั่นเพื่อหา top 10 keywords สำหรับแต่ละปี (แก้ปัญหาตัวพิมพ์ใหญ่-พิมพ์เล็ก)
def top_keywords_by_year(data):
    result = {}
    for year in data['publication_year'].unique():
        # กรองข้อมูลตามปี
        year_data = data[data['publication_year'] == year]
        
        # รวม keywords ทั้งหมดในปีนั้น และแปลงเป็นตัวพิมพ์เล็ก
        all_keywords = [keyword.lower() for keywords in year_data['keywords_list'] for keyword in keywords]
        
        # นับจำนวนแต่ละคำ
        keyword_counts = Counter(all_keywords)
        
        # หา top 10 keyword ในปีนั้น
        result[year] = keyword_counts.most_common(10)
    
    return result

# เรียกใช้ฟังก์ชั่นเพื่อหา top 10 keyword ตามปี
top_10_keywords_by_year = top_keywords_by_year(selected_data)

# เขียนผลลัพธ์ลง CSV แยกไฟล์ตามปี
for year, top_keywords in top_10_keywords_by_year.items():
    # แปลงผลลัพธ์เป็น DataFrame
    df = pd.DataFrame(top_keywords, columns=['Keyword', 'Count'])
    
    # เขียนลงไฟล์ CSV
    filename = f"top_10_keywords_{year}.csv"
    df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"บันทึก {filename} สำเร็จ!")

# แสดงผลลัพธ์บนหน้าจอ (อาจเป็นตัวเลือกเสริม)
for year, top_keywords in top_10_keywords_by_year.items():
    print(f"Top 10 keywords in {year}:")
    for keyword, count in top_keywords:
        print(f"- {keyword}: {count}")
    print()
# Out:
# บันทึก top_10_keywords_2018.csv สำเร็จ!
# บันทึก top_10_keywords_2019.csv สำเร็จ!
# บันทึก top_10_keywords_2020.csv สำเร็จ!
# บันทึก top_10_keywords_2021.csv สำเร็จ!
# บันทึก top_10_keywords_2022.csv สำเร็จ!
# บันทึก top_10_keywords_2023.csv สำเร็จ!
# Top 10 keywords in 2018:
# - thailand: 85
# - hadron-hadron scattering (experiments): 58
# - inflammation: 29
# - cms: 27
# - physics: 25
# - beyond standard model: 22
# - depression: 21
# - hiv: 19
# - cytotoxicity: 17
# - meta-analysis: 17
#
# Top 10 keywords in 2019:
# - thailand: 77
# - hadron-hadron scattering (experiments): 35
# - inflammation: 31
# - cms: 22
# - hiv: 20
# - adsorption: 18
# - oxidative stress: 18
# - physics: 15
# - beyond standard model: 15
# - machine learning: 15
#
# Top 10 keywords in 2020:
# - thailand: 96
# - covid-19: 31
# - hadron-hadron scattering (experiments): 31
# - inflammation: 28
# - asia: 23
# - depression: 20
# - hiv: 20
# - cms: 20
# - oxidative stress: 20
# - deep learning: 18
#
# Top 10 keywords in 2021:
# - thailand: 127
# - covid-19: 75
# - inflammation: 47
# - hadron-hadron scattering (experiments): 28
# - sars-cov-2: 28
# - depression: 25
# - machine learning: 25
# - oxidative stress: 25
# - biomarkers: 21
# - meta-analysis: 18
#
# Top 10 keywords in 2022:
# - thailand: 150
# - covid-19: 110
# - machine learning: 42
# - sars-cov-2: 40
# - inflammation: 39
# - deep learning: 29
# - hadron-hadron scattering: 26
# - distribution: 26
# - oxidative stress: 23
# - middle east: 23
#
# Top 10 keywords in 2023:
# - thailand: 89
# - covid-19: 64
# - machine learning: 34
# - sars-cov-2: 30
# - inflammation: 27
# - antioxidant: 26
# - hiv: 17
# - deep learning: 17
# - oxidative stress: 16
# - biodiesel: 15

# %%
# ฟังก์ชั่นเพื่อดึงและจัดเรียงทุก keyword สำหรับแต่ละปี
def all_keywords_by_year_sorted(data):
    result = {}
    for year in data['publication_year'].unique():
        # กรองข้อมูลตามปี
        year_data = data[data['publication_year'] == year]
        
        # รวม keywords ทั้งหมดในปีนั้น และแปลงเป็นตัวพิมพ์เล็ก
        all_keywords = [keyword.lower() for keywords in year_data['keywords_list'] for keyword in keywords]
        
        # นับจำนวนแต่ละคำและเรียงลำดับจากมากไปน้อย
        keyword_counts = Counter(all_keywords).most_common()
        
        # เก็บผลลัพธ์ที่เรียงแล้ว
        result[year] = keyword_counts
    
    return result

# เรียกใช้ฟังก์ชั่นเพื่อดึงทุก keyword ตามปี
all_keywords_by_year_result = all_keywords_by_year_sorted(selected_data)

# เขียนผลลัพธ์ลง CSV แยกไฟล์ตามปี
for year, keywords in all_keywords_by_year_result.items():
    # แปลงผลลัพธ์เป็น DataFrame
    df = pd.DataFrame(keywords, columns=['Keyword', 'Count'])
    
    # เขียนลงไฟล์ CSV
    filename = f"all_keywords_{year}.csv"
    df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"บันทึก {filename} สำเร็จ!")

# แสดงผลลัพธ์บนหน้าจอ (อาจเป็นตัวเลือกเสริม)
for year, keywords in all_keywords_by_year_result.items():
    print(f"All keywords in {year}:")
    for keyword, count in keywords:
        print(f"- {keyword}: {count}")
    print()
# Out:
# บันทึก all_keywords_2018.csv สำเร็จ!
# บันทึก all_keywords_2019.csv สำเร็จ!
# บันทึก all_keywords_2020.csv สำเร็จ!
# บันทึก all_keywords_2021.csv สำเร็จ!
# บันทึก all_keywords_2022.csv สำเร็จ!
# บันทึก all_keywords_2023.csv สำเร็จ!
# All keywords in 2018:
# - thailand: 85
# - hadron-hadron scattering (experiments): 58
# - inflammation: 29
# - cms: 27
# - physics: 25
# - beyond standard model: 22
# - depression: 21
# - hiv: 19
# - health literacy: 4
# - formal verification: 4
# - survey: 4
# - magnetic resonance imaging: 4
# - mutation: 4
# - chemotherapy: 4
# - microbiome: 4
# - human papillomavirus: 4
# - thyroid cancer: 4
# - antimicrobial resistance: 4
# - cadmium: 4
# - major depression: 4
# - diversity: 4
# - pain: 4
# - lactic acid: 4
# - biorefinery: 4
# - ethanol: 4
# - dark matter: 4
# - variation: 4
# - rubiaceae: 4
# - risk assessment: 4
# - ads-cft correspondence: 4
# - depressive disorder: 4
# - kynurenine: 4
# - radiotherapy: 4
# - liver: 4
# - microcrystalline cellulose: 4
# - esterification: 4
# - apixaban: 4
# - outcome: 4
# - machine learning: 4
# - warfarin: 4
# - hypertension: 4
# - gold nanoparticles: 4
# - indonesia: 4
# - storage: 4
# - surface modification: 4
# - saccharomyces cerevisiae: 4
# - seroprevalence: 4
# - radiation protection: 4
# - pythiosis: 4
# - specificity: 4
# - pythium insidiosum: 4
# - polybenzoxazine: 4
# - heavy-ion collision: 4
# - gender: 4
# - jets: 4
# - neurodevelopment: 3
# - natural product: 3
# - autism spectrum disorders: 3
# - tryptophan catabolites: 3
# - hepatocellular carcinoma: 3
# - peptide nucleic acid: 3
# - long short-term memory: 3
# - pharmacokinetics: 3
# - periodontitis: 3
# - lepton production: 3
# - research: 3
# - submillimeter: galaxies: 3
# - design: 3
# - solid oxide fuel cell: 3
# - plasmodium vivax: 3
# - stein’s method: 3
# - napier grass: 3
# - creatinine: 3
# - doxorubicin: 3
# - alzheimer's disease: 3
# - nasopharyngeal cancer: 3
# - self-management: 3
# - paper-based analytical devices: 3
# - viscosity: 3
# - flexural strength: 3
# - concrete: 3
# - controlled release: 3
# - encapsulation: 3
# - hydrogen sulfide: 3
# - vanadium oxides: 3
# - compressive strength: 3
# - vibrio parahaemolyticus: 3
# - water: 3
# - multi-class classification: 3
# - neurology: 3
# - heavy metals: 3
# - cervical cancer: 3
# - reforming: 3
# - simulation: 3
# - probiotics: 3
# - dft calculation: 3
# - x-ray analysis: 3
# - β-cyclodextrin: 3
# - classification: 3
# - surfactant: 3
# - hydrolysis: 3
# - cross section: 3
# - biodegradation: 3
# - plasticizer: 3
# - ammonia-oxidizing bacteria: 3
# - perception: 3
# - heart: 3
# - dexamethasone: 3
# - reactive oxygen species: 3
# - osteogenic differentiation: 3
# - knowledge: 3
# - mental health: 3
# - pediatric: 3
# - recycling: 3
# - photosynthesis: 3
# - human: 3
# - periodontal ligament: 3
# - timed petri nets: 3
# - cyclodextrin: 3
# - drug delivery: 3
# - adolescents: 3
# - cyclodextrins: 3
# - antifungal: 3
# - bacillus: 3
# - indoleamine 2,3-dioxygenase: 3
# - basalt: 3
# - cambodia: 3
# - crystallinity: 3
# - systematic review: 3
# - genotyping: 3
# - mitochondrial dna: 3
# - phylogeny: 3
# - south-east asia: 3
# - papillary thyroid carcinoma: 3
# - transcriptome: 3
# - older adults: 3
# - silver nanoparticles: 3
# - wound dressing: 3
# - tenofovir: 3
# - gold mine: 3
# - diffusion: 3
# - aging: 3
# - kidney: 3
# - dna barcoding: 3
# - polycaprolactone: 3
# - alzheimer’s disease: 1
# - neurotoxicity: 1
# - parkinson’s disease: 1
# - sigma-1 receptor: 1
# - inkjet printing: 1
# - paper-based devices: 1
# - patterning: 1
# - three dimensional: 1
# - back-propagation learning: 1
# - heart disease: 1
# - k-nearest neighbor method: 1
# - multi-layer perceptron: 1
# - naï ve bayes approach: 1
# - carbamazepine: 1
# - hematite nanoparticles: 1
# - nanoremediation: 1
# - removal: 1
# - tail void grout: 1
# - tunnel liner: 1
# - word: 1
# - electrochemical dna chip: 1
# - inno-lipa: 1
# - nested-pcr: 1
# - next-generation sequencing: 1
# - contrast-induced nephropathy: 1
# - species delimitation: 1
# - bartonella: 1
# - bartonella endocarditis: 1
# - bartonella henselae: 1
# - culture-negative endocarditis: 1
# - disseminated bartonella henselae infection: 1
# - interaction parameter: 1
# - interaction pattern and volume: 1
# - saigon river: 1
# - ag-doped cacu3ti4o12: 1
# - h2s sensor: 1
# - attb: 1
# - mrsa: 1
# - mssa: 1
# - orfx: 1
# - sccmec: 1
# - co-worker support: 1
# - employee retention: 1
# - employment sustainment: 1
# - intention to quit: 1
# - supervisor support: 1
# - caryophyllene oxide: 1
# - lemon basil: 1
# - ocimum citriodorum vis.: 1
# - straw: 1
# - supercritical carbon dioxide: 1
# - autosomal microsatellites: 1
# - spatial genetic structure: 1
# - y-chromosome: 1
# - competency: 1
# - global: 1
# - international nursing: 1
# - alcohol dependence: 1
# - aldh2: 1
# - flushing reaction: 1
# - genomewide association study: 1
# - early mortality syndrome: 1
# - hemocyte: 1
# - endemic fluoride area: 1
# - gis: 1
# - google maps: 1
# - safe drinking water: 1
# - water supply: 1
# - dental educators: 1
# - educator roles and competences: 1
# - thyroid: 1
# - thyroidectomy: 1
# - 3d reconstruction: 1
# - multi-view normal integration: 1
# - multi-view vision: 1
# - triangle mesh-based surface: 1
# - coacervate: 1
# - hvocs: 1
# - octanol-water partition coefficient: 1
# - vacuum stripping: 1
# - galaxies: high redshift: 1
# - galaxies: ism-galaxies: star formation: 1
# - citizenship: 1
# - human trafficking: 1
# - migrant worker: 1
# - undocumented labor: 1
# - learning management system (lms): 1
# - mycourseville (mycv): 1
# - user survey: 1
# - aki biomarkers: 1
# - renal angina: 1
# - national strategic plan: 1
# - one health: 1
# - policy: 1
# - assistive device: 1
# - soft exoskeleton: 1
# - multi model hmm: 1
# - multi-space probability distribution hmm: 1
# - dtpa: 1
# - edta: 1
# - water hyacinth: 1
# - fine root dynamics: 1
# - litter-addition: 1
# - litter-removal: 1
# - litterfall: 1
# - nitrogen: 1
# - panama: 1
# - a3. molecular beam epitaxy: 1
# - b2. insb twin nano-stripes: 1
# - (+)-α-tocuspirone: 1
# - dalbergia velutina: 1
# - alcohol use disorder: 1
# - late triassic foraminifera: 1
# - northern laos: 1
# - sukhothai zone: 1
# - tectonostratigraphy: 1
# - “tubiphytes”-microbial reefal limestone: 1
# - pressure ulcer: 1
# - entecavir: 1
# - hbeag negative hepatitis b virus infection: 1
# - nucleos(t)ide discontinuation: 1
# - virological relapse: 1
# - benthic invertebrates: 1
# - bottom cultivation: 1
# - crassostrea belcheri: 1
# - richness: 1
# - ambulation: 1
# - arthroplasty: 1
# - local analgesia: 1
# - donnan exclusion effect: 1
# - ionic strength: 1
# - reverse osmosis: 1
# - limiting amplifier: 1
# - low frequency: 1
# - low power integrated circuit: 1
# - rssi: 1
# - wake up receiver: 1
# - fictitious flux: 1
# - globally stable observer: 1
# - synchronous reluctance motors: 1
# - essential tremor: 1
# - parkinson: 1
# - pathophysiology: 1
# - tremor: 1
# - biocompatible actuator: 1
# - soft actuator: 1
# - dental pulp cells: 1
# - dentin sialophosphoprotein: 1
# - dentinal tubules: 1
# - exome sequencing: 1
# - anterior pituitary gland: 1
# - diethylstilbestrol: 1
# - pericytes: 1
# - prolactinoma: 1
# - depassion: 1
# - emotion: 1
# - face recognition: 1
# - classifiers: 1
# - color gloves: 1
# - ensemble learning: 1
# - feature element: 1
# - optical camera: 1
# - sign language: 1
# - dimethyl carbonate: 1
# - methyl ester: 1
# - scenedesmus sp.: 1
# - hybrid encryption: 1
# - multi-factor authentication: 1
# - near field communication: 1
# - network security: 1
# - smartphone: 1
# - citrate: 1
# - nadc-1: 1
# - urolithiasis: 1
# - fluorescein: 1
# - fluorescence resonance energy transfer: 1
# - histamine blue: 1
# - histamine detection: 1
# - nanoporous silica: 1
# - amd: 1
# - gossan: 1
# - waste rock: 1
# - bit error rate (ber): 1
# - mobile ad-hoc network (manet): 1
# - olsr: 1
# - quality of service (qos): 1
# - weighted connectivity index: 1
# - colonoscopy: 1
# - convolutional network: 1
# - polyp detection: 1
# - real-time detection: 1
# - video frame segmentation: 1
# - contextual variation: 1
# - contrastive evidence: 1
# - cross-linguistic semantics: 1
# - generic: 1
# - impersonal pronouns: 1
# - speaker reference: 1
# - ganglion cell complex: 1
# - optic nerve head: 1
# - racial differences: 1
# - retinal nerve fiber layer thickness: 1
# - clavicle: 1
# - coracohumeral ligament: 1
# - coracoid process: 1
# - glenohumeral joint capsule: 1
# - pectoralis minor muscle: 1
# - colloids: 1
# ...
# - groundwater models: 1
# - kriging interpolation: 1
# - monitoring network design: 1
# - saltwater intrusion: 1
# - cell disruption: 1
# - lipid extraction: 1
# - omega-3: 1
# - protein expression: 1
# - recombinant peptide: 1
# - corgi: 1
# - healthy: 1
# - heart: 1
# - column-reactors: 1
# - design: 1
# - photobioreactors: 1
# - scale-up: 1
# - financial feasibility: 1
# - fuel switching: 1
# - greenhouse gas mitigation: 1
# - industrial sector: 1
# - biosynthesis: 1
# - rheology: 1
# - thermal analysis (tga & dta): 1
# - neutrophil extracellular traps: 1
# - vitamin c: 1
# - percutaneous endoscopic lumbar discectomy: 1
# - transforaminal endoscopic discectomy: 1
# - (k: 1
# - ψ)-hilfer fractional derivative: 1
# - fixed-point theorems: 1
# - impulsive conditions: 1
# - nonlocal conditions: 1
# - ulam stability: 1
# - in situ synthesis: 1
# - silk fabric: 1
# - uv protection: 1
# - orf3a: 1
# - spermidine: 1
# - dielectric: 1
# - hydrogen economy: 1
# - metal alloy: 1
# - sensors: 1
# - waveguide: 1
# - cell sheet technique: 1
# - rice bran: 1
# - foraminotomy: 1
# - full-endoscopic: 1
# - lumbar foraminal stenosis: 1
# - o-arm navigation: 1
# - corona discharge: 1
# - hvdc: 1
# - overhead lines: 1
# - 16-psk: 1
# - free space optical communication: 1
# - ofdm: 1
# - rain and cloud attenuation: 1
# - bupivacaine: 1
# - cervical facet arthropathy: 1
# - cervical facet syndrome: 1
# - lidocaine: 1
# - medial branch block: 1
# - healthcare-associated urinary tract infection: 1
# - tertiary care hospital: 1
# - alginate particles: 1
# - burst release: 1
# - delivery system: 1
# - gas-generating agent: 1
# - tympanic membrane: 1

# %%
selected_data.head()
# Out:
#     filename                                              title  \
# 0  201800282  Recent developments in bifunctional air electr...
# 1  201801350  The benefit of punishment sensitivity on motor...
# 2  201801162  MAGIC biomarkers predict long-term outcomes fo...
# 3  201801506  Are endocrine disrupting compounds environment...
# 5  201801734  Optimization of cinnamon oil nanoemulsions usi...
#
#                                         subject_name    subject_abbreviation  \
# 0  Renewable Energy, Sustainability and the Envir...  ENER, ENER, PHYS, ENER
# 1                                  Social Psychology                    PSYC
# 2  Biochemistry, Immunology, Hematology, Cell Bio...  BIOC, IMMU, MEDI, BIOC
# 3  Endocrinology, Endocrine and Autonomic Systems...        BIOC, NEUR, NEUR
# 5  Electronic, Optical and Magnetic Materials, Bi...  MATE, MATE, MATE, CENG
#
#              subject_code         supergroup  \
# 0  2105, 2103, 3104, 2102  Physical Sciences
# 1                    3207    Social Sciences
# 2  1303, 2403, 2720, 1307  Multidisciplinary
# 3        1310, 2807, 2802      Life Sciences
# 5  2504, 2502, 2508, 1505  Physical Sciences
#
#                                             keywords  publication_year  \
# 0  Bifunctional air electrode, Catalyst support, ...              2018
# 1  anxiety, defensive distance, performance, rein...              2018
# 2                                         No keyword              2018
# 3  Autism, Endocrine disrupting compounds, Epigen...              2018
# 5  Cinnamon oil, Nanoemulsions, Natural product, ...              2018
#
#    age_of_paper aggregation_type  reference_count  \
# 0             6          Journal               89
# 1             6          Journal               44
# 2             6          Journal               30
# 3             6          Journal              128
# 5             6          Journal               43
#
#                                publisher  has_funding_info  citation_count  \
# 0                           Elsevier Ltd                 1              29
# 1               Blackwell Publishing Ltd                 0               2
# 2         American Society of Hematology                 1             117
# 3  Academic Press Inc.apjcs@harcourt.com                 1              51
# 5  Academic Press Inc.apjcs@harcourt.com                 1              93
#
#    open_access                                      keywords_list
# 0            0  [Bifunctional air electrode, Catalyst support,...
# 1            2  [anxiety, defensive distance, performance, rei...
# 2            1                                                 []
# 3            1  [Autism, Endocrine disrupting compounds, Epige...
# 5            0  [Cinnamon oil, Nanoemulsions, Natural product,...

# %%
selected_data.to_csv('selected_data.csv', index=False)

# %%
missing_values = selected_data.isnull().sum()
print("Missing Values per Column:")
print(missing_values)
# Out:
# Missing Values per Column:
# filename                0
# title                   0
# subject_name            0
# subject_abbreviation    0
# subject_code            0
# supergroup              0
# keywords                0
# publication_year        0
# age_of_paper            0
# aggregation_type        0
# reference_count         0
# publisher               0
# has_funding_info        0
# citation_count          0
# open_access             0
# keywords_list           0
# dtype: int64
